# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasCastrosb/Dados/blob/main/JogoForca2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import random
 from os import system, name

# %%
#função para limpar tela
def limpa_tela():
  if name == 'nt':
    _ = system('cls')
  else:
    _ = system('clear')

# %%
def display_hangman(chances):

    # Lista de estágios da forca
    stages = [  # estágio 6 (final)
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                   -
                """,
                # estágio 5
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     /
                   -
                """,
                # estágio 4
                """
                   --------
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |
                   -
                """,
                # estágio 3
                """
                   --------
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |
                   -
                """,
                # estágio 2
                """
                   --------
                   |      |
                   |      O
                   |      |
                   |      |
                   |
                   -
                """,
                # estágio 1
                """
                   --------
                   |      |
                   |      O
                   |
                   |
                   |
                   -
                """,
                # estágio 0
                """
                   --------
                   |      |
                   |
                   |
                   |
                   |
                   -
                """
    ]
    return stages[chances]

# %%
def game():
  limpa_tela()
  print("Bem-vindo(a) ao jogo da forca!")
  print("Adivinhe a palavra abaixo:\n")

# %%
palavras = ['banana', 'abacate', 'uva', 'morango', 'laranja']

# %%
palavra = random.choice(palavras)

# %%
lista_letras_palavras = [letra for letra in palavra]

# %%
tabuleiro = ["_"] * len(palavra)

# %%
chances = 6

# %%
    letras_tentativas = []

# %%
 while chances > 0:

        print(display_hangman(chances))
        print("Palavra: ", tabuleiro)
        print("\n")

        # Tentativa
        tentativa = input("\nDigite uma letra: ")

        # Condicional
        if tentativa in letras_tentativas:
            print("Você já tentou essa letra. Escolha outra!")
            continue

        # Lista de tentativas (letras)
        letras_tentativas.append(tentativa)

        # Condicional
        if tentativa in lista_letras_palavras:

            print("Você acertou a letra!")

            # Loop
            for indice in range(len(lista_letras_palavras)):

                # Condicional
                if lista_letras_palavras[indice] == tentativa:
                    tabuleiro[indice] = tentativa

            # Se todos os espaços foram preenchidos, o jogo acabou
            if "_" not in tabuleiro:
                print("\nVocê venceu! A palavra era: {}".format(palavra))
                break
        else:
            print("Ops. Essa letra não está na palavra!")
            # Decremento
            chances -= 1

    # Condicional
if "_" in tabuleiro:
        print("\nVocê perdeu! A palavra era: {}.".format(palavra))
# Out:
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# Palavra:  ['_', '_', '_', '_', '_', '_', '_']
#
#
#
# Digite uma letra: a
# Você acertou a letra!
#
#                    --------
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                    -
#
# Palavra:  ['_', '_', '_', 'a', '_', '_', '_']
#
#
#
# Digite uma letra: b
# Ops. Essa letra não está na palavra!
#
#                    --------
#                    |      |
#                    |      O
#                    |
#                    |
#                    |
#                    -
#
# Palavra:  ['_', '_', '_', 'a', '_', '_', '_']
#
#
#
# Digite uma letra: e
# Ops. Essa letra não está na palavra!
#
#                    --------
#                    |      |
#                    |      O
#                    |      |
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', '_', '_', 'a', '_', '_', '_']
#
#
#
# Digite uma letra: r
# Você acertou a letra!
#
#                    --------
#                    |      |
#                    |      O
#                    |      |
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', '_', 'r', 'a', '_', '_', '_']
#
#
#
# Digite uma letra: i
# Ops. Essa letra não está na palavra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', '_', 'r', 'a', '_', '_', '_']
#
#
#
# Digite uma letra: o
# Você acertou a letra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: e
# Você já tentou essa letra. Escolha outra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: e
# Você já tentou essa letra. Escolha outra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: a
# Você já tentou essa letra. Escolha outra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: e
# Você já tentou essa letra. Escolha outra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: r
# Você já tentou essa letra. Escolha outra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: q
# Ops. Essa letra não está na palavra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', '_', '_', 'o']
#
#
#
# Digite uma letra: n
# Você acertou a letra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |
#                    -
#
# Palavra:  ['_', 'o', 'r', 'a', 'n', '_', 'o']
#
#
#
# Digite uma letra: m
# Você acertou a letra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |
#                    -
#
# Palavra:  ['m', 'o', 'r', 'a', 'n', '_', 'o']
#
#
#
# Digite uma letra: j
# Ops. Essa letra não está na palavra!
#
#                    --------
#                    |      |
#                    |      O
#                    |     \|/
#                    |      |
#                    |     /
#                    -
#
# Palavra:  ['m', 'o', 'r', 'a', 'n', '_', 'o']
#
#
#
# Digite uma letra: k
# Ops. Essa letra não está na palavra!
#
# Você perdeu! A palavra era: morango.
